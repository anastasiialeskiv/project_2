# %%
import plotly as py
import plotly.graph_objs as go
py.offline.init_notebook_mode(connected=True)
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
from statsmodels.formula.api import ols

import seaborn as sns
from sklearn.linear_model import LinearRegression
import scipy.stats as stats
# %matplotlib inline
import plotly
plotly.offline.init_notebook_mode(connected=True)
import plotly.offline as py
import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
regression_lineD = reg_line(m,c,df['yr_built'])

# %%
plt.scatter(df['yr_built'], df['price'], color='#003F72', label='Data points')
plt.plot(df['yr_built'], regression_lineD, label='Regression Line')
plt.legend()
plt.xlabel('Square Feet ot the Land Space')
plt.ylabel('Price')
plt.title('Square Feet ot the Land Space vs. Price')
plt.show()

# %%
# make predictions using test data and put it in a pandas dataframe
preds = pd.DataFrame(dummy_model1.predict(), columns=['price_pred'])

# %%
preds.head()

# %%
m = build_model(df, 'price')
print('Mean Residuals is: {}'.format(m.resid.abs().mean()))
m.summary()

# %%
# preview the location and yr_renovated 
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['long'],
               y=df['lat'], 
                hue=df['yr_renovated'], x_bins='auto')
plt.title('renovated year')
plt.show()

# %%
df['yr_renovated'].describe()
# Out:
# count   30155.00
# mean       90.92
# std       416.47
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max      2022.00
# Name: yr_renovated, dtype: float64

# %% [markdown]
# As I could see none of the houses were remodeled

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price',palette='RdBu',alpha=0.2)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
# preview the location and price
plt.figure(figsize=(12,10))
sns.scatterplot(x=df['long'],
               y=df['lat'], 
                hue=df['price'], x_bins='auto')
plt.title('Price')
plt.show()

# %%
df['price'].describe()
# Out:
# count      30155.00
# mean     1108535.84
# std       896385.66
# min        27360.00
# 25%       648000.00
# 50%       860000.00
# 75%      1300000.00
# max     30750000.00
# Name: price, dtype: float64

# %%
df['price']
# Out:
# 0        675000.00
# 1        920000.00
# 2        311000.00
# 3        775000.00
# 4        592500.00
#            ...
# 30150   1555000.00
# 30151   1313000.00
# 30152    800000.00
# 30153    775000.00
# 30154    500000.00
# Name: price, Length: 30155, dtype: float64

# %%
# preview the location and yr_built
plt.figure(figsize=(12,10))
sns.scatterplot(x=df['long'],
               y=df['lat'], 
                hue=df['yr_built'], x_bins='auto')
plt.title('Year built')
plt.show()

# %%
# preview the location and price
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['long'],
               y=df['lat'], 
                hue=df['grade'], x_bins='auto')
plt.title('Grade')
plt.show()

# %% [markdown]
# Newest houses are
# Oldest houses are in West Seattle
# New Remodeled
# Higer price for the house
# Lower price for the house
# The most popular area by the grade
